# %% [markdown]
# # 📊 Análise de Acidentes de Trânsito no Brasil
#
# Este notebook apresenta uma análise exploratória de dados (EDA) sobre acidentes de trânsito registrados no Brasil.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar dados
df = pd.read_csv('../dados/acidentes_brasil.csv')
df.head()
